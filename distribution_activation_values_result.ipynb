# %% [markdown]
# Connected to ryo_venv

# %%
for feature in features_lst:
    print(f'{print_feature(feature)}: {features_to_supernodes[feature]}')
    print('English sentences')
    make_histogram_from_values_dict(en_values[feature])
    print('French sentences')
    make_histogram_from_values_dict(fr_values[feature])
    print('German sentences')
    make_histogram_from_values_dict(de_values[feature])
    print('Chinese sentences')
    make_histogram_from_values_dict(zh_values[feature])
    print('Japanese sentences')
    make_histogram_from_values_dict(ja_values[feature])
    print('-----------------------------------------------')
# Out:
# Layer 20, feature_idx 1194: ['Japanese']
# English sentences
# Total NaN values found: 99
# Max 27.25, Min 27.25, Mean 27.25, Median 27.25
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 88
# Max 29.25, Min 7.75, Mean 19.114583333333332, Median 20.625
# -----------------------------------------------
# Layer 23, feature_idx 7105: ['German']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 6
# Max 119.5, Min 9.125, Mean 78.60505319148936, Median 87.0
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 24, feature_idx 15582: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 1
# Max 159.0, Min 48.25, Mean 101.96717171717172, Median 103.0
# Japanese sentences
# Total NaN values found: 0
# Max 205.0, Min 43.5, Mean 141.7375, Median 149.0
# -----------------------------------------------
# Layer 24, feature_idx 5020: ['German']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 28
# Max 125.0, Min 6.5, Mean 34.6875, Median 26.5
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 24, feature_idx 13785: ['Non English']
# English sentences
# Total NaN values found: 82
# Max 104.5, Min 6.9375, Mean 35.427083333333336, Median 23.0
# French sentences
# Total NaN values found: 78
# Max 89.5, Min 7.3125, Mean 47.15909090909091, Median 49.875
# German sentences
# Total NaN values found: 54
# Max 127.5, Min 6.9375, Mean 52.98233695652174, Median 53.0
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 25, feature_idx 11677: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 6
# Max 112.5, Min 9.375, Mean 61.799202127659576, Median 62.0
# -----------------------------------------------
# Layer 20, feature_idx 1454: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 3
# Max 56.25, Min 15.0625, Mean 37.1610824742268, Median 37.25
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 24, feature_idx 9590: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 6
# Max 178.0, Min 13.25, Mean 88.42021276595744, Median 88.25
# -----------------------------------------------
# Layer 24, feature_idx 3772: ['French']
# English sentences
# Total NaN values found: 95
# Max 17.5, Min 7.4375, Mean 10.375, Median 8.9375
# French sentences
# Total NaN values found: 0
# Max 113.5, Min 30.25, Mean 83.9525, Median 83.25
# German sentences
# Total NaN values found: 99
# Max 11.6875, Min 11.6875, Mean 11.6875, Median 11.6875
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 22, feature_idx 10921: ['German']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 11
# Max 143.0, Min 10.0, Mean 81.63764044943821, Median 87.0
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 21, feature_idx 7092: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 95
# Max 21.375, Min 8.875, Mean 13.775, Median 11.5
# German sentences
# Total NaN values found: 98
# Max 15.375, Min 8.0, Mean 11.6875, Median 11.6875
# Chinese sentences
# Total NaN values found: 99
# Max 8.125, Min 8.125, Mean 8.125, Median 8.125
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 23, feature_idx 2876: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 48
# Max 60.75, Min 6.625, Mean 21.57451923076923, Median 20.875
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 21, feature_idx 9438: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 22
# Max 77.5, Min 8.375, Mean 38.11057692307692, Median 34.75
# -----------------------------------------------
# Layer 20, feature_idx 12763: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 97
# Max 55.0, Min 46.5, Mean 51.0, Median 51.5
# -----------------------------------------------
# Layer 23, feature_idx 2592: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 2
# Max 97.0, Min 8.0, Mean 61.077806122448976, Median 66.0
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 25, feature_idx 14642: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 99
# Max 7.25, Min 7.25, Mean 7.25, Median 7.25
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 52
# Max 44.5, Min 6.25, Mean 21.802083333333332, Median 19.125
# -----------------------------------------------
# Layer 23, feature_idx 13630: ['Chinese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 1
# Max 86.0, Min 14.125, Mean 47.82828282828283, Median 48.0
# Japanese sentences
# Total NaN values found: 99
# Max 9.75, Min 9.75, Mean 9.75, Median 9.75
# -----------------------------------------------
# Layer 24, feature_idx 4348: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 34
# Max 95.0, Min 6.625, Mean 26.111742424242426, Median 22.75
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 20, feature_idx 15832: ['German']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 5
# Max 84.5, Min 10.75, Mean 58.98421052631579, Median 59.5
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 23, feature_idx 10329: ['Chinese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 50
# Max 65.5, Min 6.25, Mean 18.6725, Median 15.25
# Japanese sentences
# Total NaN values found: 96
# Max 11.875, Min 6.25, Mean 8.4375, Median 7.8125
# -----------------------------------------------
# Layer 23, feature_idx 11714: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 88
# Max 37.5, Min 6.125, Mean 15.291666666666666, Median 14.25
# -----------------------------------------------
# Layer 18, feature_idx 1831: ['Non English']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 99
# Max 11.375, Min 11.375, Mean 11.375, Median 11.375
# German sentences
# Total NaN values found: 99
# Max 7.875, Min 7.875, Mean 7.875, Median 7.875
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 23, feature_idx 10930: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 15
# Max 60.75, Min 6.375, Mean 26.89264705882353, Median 26.75
# -----------------------------------------------
# Layer 18, feature_idx 15383: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 68
# Max 23.25, Min 6.3125, Mean 12.68359375, Median 12.0625
# -----------------------------------------------
# Layer 20, feature_idx 13373: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 78
# Max 84.0, Min 6.6875, Mean 38.78693181818182, Median 38.125
# -----------------------------------------------
# Layer 25, feature_idx 15066: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 2
# Max 112.0, Min 9.0, Mean 52.15816326530612, Median 50.5
# Japanese sentences
# Total NaN values found: 14
# Max 104.0, Min 6.5, Mean 46.56976744186046, Median 37.75
# -----------------------------------------------
# Layer 16, feature_idx 13082: ['Chinese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 24, feature_idx 3939: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 31
# Max 93.0, Min 6.4375, Mean 38.95108695652174, Median 38.75
# -----------------------------------------------
# Layer 24, feature_idx 15163: ['Chinese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 1
# Max 151.0, Min 61.5, Mean 105.5959595959596, Median 107.0
# Japanese sentences
# Total NaN values found: 99
# Max 54.5, Min 54.5, Mean 54.5, Median 54.5
# -----------------------------------------------
# Layer 24, feature_idx 9342: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 92
# Max 98.0, Min 21.25, Mean 69.1875, Median 74.0
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 24, feature_idx 406: ['Non English', 'Chinese', 'Japanese']
# English sentences
# Total NaN values found: 96
# Max 43.25, Min 15.125, Mean 28.71875, Median 28.25
# French sentences
# Total NaN values found: 38
# Max 69.0, Min 6.5, Mean 26.848790322580644, Median 23.375
# German sentences
# Total NaN values found: 39
# Max 98.0, Min 6.5, Mean 40.55327868852459, Median 35.25
# Chinese sentences
# Total NaN values found: 1
# Max 115.0, Min 9.0, Mean 60.04671717171717, Median 64.5
# Japanese sentences
# Total NaN values found: 0
# Max 117.0, Min 40.5, Mean 85.795, Median 86.25
# -----------------------------------------------
# Layer 22, feature_idx 11933: ['Chinese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 1
# Max 75.0, Min 10.875, Mean 51.00757575757576, Median 52.5
# Japanese sentences
# Total NaN values found: 93
# Max 42.5, Min 7.875, Mean 16.339285714285715, Median 13.5
# -----------------------------------------------
# Layer 23, feature_idx 7305: ['German']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 84
# Max 111.0, Min 9.25, Mean 36.6875, Median 20.5
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 22, feature_idx 10566: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 1
# Max 130.0, Min 12.5, Mean 84.8459595959596, Median 88.5
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 19, feature_idx 15088: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 79
# Max 36.0, Min 10.375, Mean 26.13095238095238, Median 25.875
# -----------------------------------------------
# Layer 22, feature_idx 2896: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 63
# Max 42.25, Min 8.0, Mean 16.486486486486488, Median 14.125
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 22, feature_idx 4400: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 1
# Max 118.5, Min 10.875, Mean 77.9090909090909, Median 81.5
# -----------------------------------------------
# Layer 23, feature_idx 5535: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 93
# Max 66.5, Min 8.0, Mean 29.375, Median 22.125
# -----------------------------------------------
# Layer 23, feature_idx 3683: ['Non English']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 98
# Max 9.25, Min 6.75, Mean 8.0, Median 8.0
# German sentences
# Total NaN values found: 98
# Max 9.875, Min 9.75, Mean 9.8125, Median 9.8125
# Chinese sentences
# Total NaN values found: 95
# Max 16.75, Min 6.75, Mean 11.25, Median 10.0
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 18, feature_idx 402: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 93
# Max 21.0, Min 6.3125, Mean 10.071428571428571, Median 7.1875
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 21, feature_idx 11819: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 84
# Max 52.25, Min 7.75, Mean 15.8359375, Median 11.625
# German sentences
# Total NaN values found: 95
# Max 26.5, Min 10.0, Mean 14.85, Median 11.875
# Chinese sentences
# Total NaN values found: 99
# Max 7.875, Min 7.875, Mean 7.875, Median 7.875
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 23, feature_idx 2557: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 61
# Max 27.5, Min 6.125, Mean 11.907051282051283, Median 11.0
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 19, feature_idx 855: ['German']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 91
# Max 19.5, Min 9.8125, Mean 12.70138888888889, Median 10.6875
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 24, feature_idx 3321: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 7
# Max 95.0, Min 8.75, Mean 40.10349462365591, Median 38.5
# -----------------------------------------------
# Layer 23, feature_idx 10748: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 92
# Max 33.75, Min 9.3125, Mean 21.4609375, Median 23.625
# German sentences
# Total NaN values found: 99
# Max 8.4375, Min 8.4375, Mean 8.4375, Median 8.4375
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 23, feature_idx 10513: ['French']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 41
# Max 37.25, Min 6.375, Mean 16.305084745762713, Median 14.25
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
# Layer 14, feature_idx 14335: ['Japanese']
# English sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# French sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# German sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Chinese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# Japanese sentences
# Total NaN values found: 100
# No valid data points to plot after excluding NaNs.
# -----------------------------------------------
